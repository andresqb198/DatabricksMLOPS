# %%
from trainer_mlops import Trainer
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data", header=None)

# %%
trainer = Trainer(df=df)
trainer.split_data(test_size=0.3,random_state=42)
trainer.add_model(model=RandomForestClassifier(random_state=42),model_name="Random Forest")

# %%
trainer.run_mlflow()
trainer.draw_confusion_matrix()
# Out:
# 2024/12/06 16:07:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        14
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
